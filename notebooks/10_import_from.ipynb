# %%
from templates import *
from templates import my_bar_plot

# %%
df = pd.read_csv("../data/processed/instacart.csv")
df.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   1187899        1            11          4                  8
# 1           1   1187899        1            11          4                  8
# 2           2   1187899        1            11          4                  8
# 3           3   1187899        1            11          4                  8
# 4           4   1187899        1            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                    14.0         196                  1          1  ...
# 1                    14.0       25133                  2          1  ...
# 2                    14.0       38928                  3          1  ...
# 3                    14.0       26405                  4          1  ...
# 4                    14.0       39657                  5          1  ...
#
# ...

# %%
# Example: Summing a numeric column (y) grouped by a category (x)
fig = my_bar_plot(
    df=df, 
    x_col='department',   # Replace with a categorical column from your CSV
    y_col='order_id',     # Replace with a numeric column to sum
    flag=True             # True highlights the Highest, False highlights the Lowest
)

# Display the plot
fig.show()
